# %% [markdown]
# # Análisis sobre una imagen capturada por un satélite
# ### Importación de la imagen en un ndarray, realizar operaciones y modificaciones, y ver el resultado de dichas modificaciones en la imagen

# %% [markdown]
# ## Importación de las librerías necesarias

# %%
# %matplotlib inline
import numpy as np
from scipy import misc
import imageio as img
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importación de la imagen capturada por el satélite, y almacenada en un ndarray

# %%
from skimage import data

photo_data = img.imread('./wifire/sd-3layers.jpg')
type(photo_data)
# Out:
# imageio.core.util.Array

# %% [markdown]
# ### Mostrar la imagen con pylot

# %%
plt.figure(figsize=(15, 15))
plt.imshow(photo_data)

# %%
photo_data.shape
# Out:
# (3725, 4797, 3)

# %% [markdown]
# La forma (shape) del ndarray indica que se trata de una matriz de tres capas. El primer número (3.275) indica la altura de la imagen, el segundo (4.797) indica la achura, y el tercero (3) indica las tres capas que forman un color, es decir, RGB.

# %% [markdown]
# <h1 style="color: gray;"><u>Mapeado del color en la imagen</u></h1>
#
# Los colores de cada uno de los píxeles de la imagen indican una información:
# <ul>
# <li><p style="font-size: 22px; color: red;"><b>ROJO</b> indica la altitud.</p></li>
# <li><p style="font-size: 22px; color: blue;"><b>AZUL</b> indica la exposición.</p></li>
# <li><p style="font-size: 22px; color: green;"><b>VERDE</b> indica la inclinación.</p></li>
# </ul>

# %%
# número de elementos del ndarray
photo_data.size
# Out:
# 53606475

# %%
# valor mínimo y máximo del ndarray
print("Valor mínimo: " + str(photo_data.min()))
print("Valor máximo: " + str(photo_data.max()))
# Out:
# Valor mínimo: 0
# Valor máximo: 255

# %%
# media del valor de los píxeles
photo_data.mean()
# Out:
# 75.8299354508947

# %% [markdown]
# ### Modificar los colores de un área de la imagen a través del ndarray

# %%
photo_data_bis = img.imread('./wifire/sd-3layers.jpg')
photo_data_bis[:, 0:500] = 255
plt.figure(figsize=(8, 8))
plt.imshow(photo_data_bis)

# %% [markdown]
# ### Modificar el área de la imagen en función de la intensidad de cada uno de los píxeles

# %%
photo_data = img.imread('./wifire/sd-3layers.jpg')
# muestro la imagen original
print("Imagen original:")
plt.figure(figsize=(8, 8))
plt.imshow(photo_data)
# Out:
# Imagen original:

# %%
# creo un ndarray con la misma estructura que el ndarray que contiene la imagen, pero con valores True o False
# en función del condicional indicado
photo_filter = photo_data < 200
# modifico los valores de los píxeles
photo_data[photo_filter] = 0
# muestro la imagen modificada
print("Imagen modificada:")
plt.figure(figsize=(8, 8))
plt.imshow(photo_data)
# Out:
# Imagen modificada:
